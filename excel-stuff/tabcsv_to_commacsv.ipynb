# %%
import os
import pandas as pd

# %%
base_path = 'C:/Users/prayme/Documents/카카오톡 받은 파일/새 폴더/to'
os.listdir(base_path)
# Out:
# ['participants_5일차.csv']

# %%
for file in os.listdir(base_path):
    tab_csv = pd.read_csv(os.path.join(base_path, file), encoding='utf-8-sig')
    for idx, row in tab_csv.iterrows():
        row = row[0].split('\t')
        
        while '' in row:
            row.remove('')
# Out:
# ['20163029', '2020-10-26 17:55', '2020-10-26 17:56', '1']
# ['무역학과20163029풍몽령 (20163029)', '2020-10-26 17:56', '2020-10-26 18:14', '19']
# ['20172100_글로벌비즈니스_김동이', '2020-10-26 17:58', '2020-10-26 17:58', '1']
# ['글로벌비즈니스_20172100_김동이 (20172100_글로벌비즈니스_김동이)', '2020-10-26 17:58', '2020-10-26 19:50', '113']
# ['이세 영', 'llssyy230@gmail.com', '2020-10-26 18:00', '2020-10-26 18:00', '1']
# ['중국경제통상학과 20161471 이세영 (이세 영)', 'llssyy230@gmail.com', '2020-10-26 18:00', '2020-10-26 19:51', '112']
# ['곽준월', '2020-10-26 18:04', '2020-10-26 18:04', '1']
# ['20163040\\무역곽준월 (곽준월)', '2020-10-26 18:04', '2020-10-26 19:51', '107']
# ['무역학과 20162934 진수', '2020-10-26 18:09', '2020-10-26 18:09', '1']
# ['무역학과 20162934 진수', '2020-10-26 18:09', '2020-10-26 19:35', '87']
# ['변주현', '2020-10-26 18:07', '2020-10-26 18:07', '1']
# ['컨벤션호텔경영학과/20181670/변주현 (변주현)', '2020-10-26 18:07', '2020-10-26 18:54', '47']
# ['무역학과20163038왕예영', '2020-10-26 18:09', '2020-10-26 18:09', '1']
# ...
